# %%
# !pip install pyperclip
# !pip install pyautogui
# !pip install yfinance

import yfinance as yf
import pyautogui
import pyperclip
import time

time.sleep(5)
pyautogui.position()

ticker = input("Digite o código da ação: ")
dados = yf.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento.plot()


fechamento.max()
fechamento.min()
fechamento[1]
fechamento[-1]

maxima = round(fechamento.max(),2)
minima = round(fechamento.min(), 2)
atual = round(fechamento[-1], 2)

print(maxima)
print(minima)
print(atual)

#dar uma pausa de 2seg
pyautogui.PAUSE = 2

# abrir uma nova aba (ctrl + t)
pyautogui.hotkey("ctrl","t")

#digitar www.gmail.com e dar um enter
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")

#clicar no botão escrever
pyautogui.click(x=-930, y=-36)

#digitar o destinatario
pyperclip.copy("arthurcadengue2@gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#digitar o assunto
pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")


#corpo do e-mail
mensagem = f"""
Prezado gestor, 

Seguem, conforme solicitado, as análises dos últimos seis meses da ação {ticker}:

Cotação máxima: R$ {maxima}
Cotação mínima: R$ {minima}
Cotação atual: R$ {atual}

Qualquer dúvida, fico á disposição!

Atte.
Arthur
"""

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

pyautogui.click(x=-526, y=1052)
print("E-mail enviado com sucesso!")
# Out:
# Requirement already satisfied: pyperclip in c:\users\arthu\anaconda3\lib\site-packages (1.8.2)
# Requirement already satisfied: pyautogui in c:\users\arthu\anaconda3\lib\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\arthu\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\arthu\anaconda3\lib\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\arthu\anaconda3\lib\site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\arthu\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\arthu\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\arthu\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyscreenshot in c:\users\arthu\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\arthu\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Requirement already satisfied: pyperclip in c:\users\arthu\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: EasyProcess in c:\users\arthu\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: entrypoint2 in c:\users\arthu\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: mss in c:\users\arthu\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Requirement already satisfied: yfinance in c:\users\arthu\anaconda3\lib\site-packages (0.2.18)
# Requirement already satisfied: requests>=2.26 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (39.0.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\arthu\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\arthu\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\arthu\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\arthu\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\arthu\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\arthu\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\arthu\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arthu\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arthu\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arthu\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: pycparser in c:\users\arthu\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Digite o código da ação: BBAS3.SA
# 44.87
# 30.18
# 44.87
# E-mail enviado com sucesso!
